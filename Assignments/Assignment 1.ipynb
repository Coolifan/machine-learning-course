# %% [markdown]
# # Assignment 1 - Probability, Linear Algebra, Programming, and Git
#
# ## *Yifan Li*
# Netid:  *yl506*

# %% [markdown]
# # Probability and Statistics Theory

# %% [markdown]
# ## 1
# Let $f(x) = \begin{cases}
#                 0           & x < 0  \\
#                 \alpha x^2  & 0 \leq x \leq 2 \\
#                 0           & 2 < x
#             \end{cases}$
#
# For what value of $\alpha$ is $f(x)$ a valid probability density function?
#
# *Note: for all assignments, write out all equations and math for all assignments using markdown and [LaTeX](https://tobi.oetiker.ch/lshort/lshort.pdf) and show all work*

# %% [markdown]
# **ANSWER**
#
# By the definition of probability density function, the cumulative distribution function $$F(x) = \int^\infty_{-\infty} f(x)dx = 1$$
#
# so we have$$F(x) = \int^2_0 \alpha x^2 = 1$$
#
# After solving the integral equation, we have $$\alpha = \frac{3}{8}$$

# %% [markdown]
# ## 2
# What is the cumulative distribution function (CDF) that corresponds to the following probability distribution function? Please state the value of the CDF for all possible values of $x$.
#
# $f(x) = \begin{cases}
#     \frac{1}{3} & 0 < x < 3 \\
#     0           & \text{otherwise}
#     \end{cases}$

# %% [markdown]
# **ANSWER**
#
# By the definition of CDF, $$F_X(x) = \int^x_{-\infty}f_X(t)dt $$
#
# So if $x<0$, $$F_X(x) = \int^0_{-\infty}0dx = 0$$
#
#    if $0<x<3$, $$F_X(x) = \int^0_{-\infty}0dx + \int^x_0\frac{1}{3}dx = \frac{x}{3} $$
#
#    and if $x>3$, $$F_X(x) = \int^3_0\frac{1}{3}dx + 0 = 1$$

# %% [markdown]
# ## 3
# For the probability distribution function for the random variable $X$,
#
# $f(x) = \begin{cases}
#     \frac{1}{3} & 0 < x < 3 \\
#     0           & \text{otherwise}
#     \end{cases}$
#
# what is the (a) expected value and (b) variance of $X$. *Show all work*.

# %% [markdown]
# **ANSWER**
#
# (a) Expected value:
# By the definition of expected value, $$E[X] = \int^\infty_{-\infty}xf(x)dx$$
#
# Here, we have $$E[X] = \int^3_0 \frac{1}{3}xdx = \frac{3}{2}$$
#
#
# (b) Variance:
# By the definition of variance, $$Var(X) = E[X^2] - E[X]^2$$
#
# And $$E[X^2] = \int^\infty_{-\infty}x^2f(x)dx = \int^3_0 \frac{1}{3}x^2dx = 3$$
# So $$Var(X) = 3 - (\frac{3}{2})^2 = \frac{3}{4}$$

# %% [markdown]
# ## 4
# Consider the following table of data that provides the values of a discrete data vector $\mathbf{x}$ of samples from the random variable $X$, where each entry in $\mathbf{x}$ is given as $x_i$.
#
# *Table 1. Dataset N=5 observations*
#
# |        | $x_0$ | $x_1$ | $x_2$ | $x_3$ | $x_4$ |
# |------  |-------|-------|-------|-------|-------|
# |$\textbf{x}$| 2     | 3     | 10    | -1    | -1    |
#
# What is the (a) mean, (b) variance, and the  of the data?
#
# *Show all work. Your answer should include the definition of mean, median, and variance in the context of discrete data.*

# %% [markdown]
# **ANSWER**
#
# (a) Mean
#
# In the case of a discrete probability distribution of a random variable $X$, the mean is equal to the sum over every possible value weighted by the probability of that value. Here, I assume that all observations have the same possibility of $\frac{1}{5}$ since we have $N = 5$. So
# $$\bar x = \frac{1}{5}(2+3+10-1-1) = 2.6$$
#
#
# (b) Variance
#
# The variance of a random variable $X$ is the expected value of the squared deviation from the mean of $X$.
# Here,
#
# $$Var(X) = \frac{1}{N}\sum\limits_{i=1}^{N}(X_i-\mu)^2 = \frac{1}{5}\sum\limits_{i=0}^{4}(X_i-2.6)^2 = 20.3$$

# %% [markdown]
# ## 5
# Review of counting from probability theory.
#
# (a) How many different 7-place licence plates are possible if the first 3 places only contain letters and te last 4 only contain numbers?
#
# (b) How many different batting orders are possible for a baseball team with 9 players?
#
# (c) How many batting orders of 5 players are possible for a team with 9 players total?
#
# (d) Let's assume this class has 26 students and we want to form project teams. How many unique teams of 3 are possible?
#
# *Hint: For each problem, determine if order matters, and if it should be calculated with or without replacement.*

# %% [markdown]
# **ANSWER**
#
# (a) In this case, order matters (ABC1234 is different from CBA1234) and it should be calculated with replacement (the same digit/letter could be used more than once). So we have $26*26*26*10*10*10*10 = 1.7576*10^8 $different licence plates
#
# (b) In this case, order matters and it should be calculated without replacement. We have $9! = 362880$ possible orders.
#
# (c) In this case, order matters and it should be calculated without replacement. We have $C^9_5 * 5! = 15120$ possible orders.
#
# (d) In this case, order does not matter and it should be calculated without replacement. We have $C^{26}_3 = \frac{26!}{23!3!} = 2600$ unique teams.

# %% [markdown]
# # Linear Algebra

# %% [markdown]
# ## 6
# **Matrix manipulations and multiplication**. Machine learning involves working with many matrices, so this exercise will provide you with the opportunity to practice those skills.
#
# Let
# $\mathbf{A} =  \begin{bmatrix}
# 1 & 2 & 3 \\
# 2 & 4 & 5 \\
# 3 & 5 & 6
# \end{bmatrix}$, $\mathbf{b} =  \begin{bmatrix}
# -1  \\
# 3  \\
# 8
# \end{bmatrix}$, $\mathbf{c} =  \begin{bmatrix}
# 4  \\
# -3  \\
# 6
# \end{bmatrix}$, and $\mathbf{I} =  \begin{bmatrix}
# 1 & 0 & 0 \\
# 0 & 1 & 0 \\
# 0 & 0 & 1
# \end{bmatrix}$
#
# Compute the following or indicate that it cannot be computed:
#
# 1. $\mathbf{A}\mathbf{A}$
# 2. $\mathbf{A}\mathbf{A}^T$
# 3. $\mathbf{A}\mathbf{b}$
# 4. $\mathbf{A}\mathbf{b}^T$
# 5. $\mathbf{b}\mathbf{A}$
# 6. $\mathbf{b}^T\mathbf{A}$
# 7. $\mathbf{b}\mathbf{b}$
# 8. $\mathbf{b}^T\mathbf{b}$
# 9. $\mathbf{b}\mathbf{b}^T$
# 10. $\mathbf{b} + \mathbf{c}^T$
# 11. $\mathbf{b}^T\mathbf{b}^T$
# 12. $\mathbf{A}^{-1}\mathbf{b}$
# 13. $\mathbf{A}\circ\mathbf{A}$
# 14. $\mathbf{b}\circ\mathbf{c}$
#
# *Note: The element-wise (or Hadamard) product is the product of each element in one matrix with the corresponding element in another matrix, and is represented by the symbol "$\circ$".*

# %% [markdown]
# ### **ANSWER**
#
# 1. $\mathbf{A}\mathbf{A} =$ $\begin{bmatrix}
#    14 & 25 & 31 \\
#    25 & 45 & 56 \\
#    31 & 56 & 70
#    \end{bmatrix} $
#
# 2. $\mathbf{A}^T = \mathbf{A}$, so the same answer as question 1, $\mathbf{A}\mathbf{A}^T =$
#    $\begin{bmatrix}
#    14 & 25 & 31 \\
#    25 & 45 & 56 \\
#    31 & 56 & 70
#    \end{bmatrix} $
#
# 3. $\mathbf{A}\mathbf{b} = $ $\begin{bmatrix}
#     29 \\
#     50 \\
#     60
#     \end{bmatrix} $
#
# 4. $\mathbf{A}\mathbf{b}^T$ cannot be computed since $\mathbf{A}$ has $3$ columns but $\mathbf{b}^T$ has $1$ row.
#
# 5. $\mathbf{b}\mathbf{A}$ cannot be computed since $\mathbf{b}$ has $1$ column but $\mathbf{A}$ has $3$ rows.
#
# 6. $\mathbf{b}^T\mathbf{A} = $ $\begin{bmatrix}
#    29 & 50 & 60 \\
#    \end{bmatrix} $
#
# 7. $\mathbf{b}\mathbf{b}$ cannot be computed since $\mathbf{b}$ has $1$ column but $3$ rows.
#
# 8. $\mathbf{b}^T\mathbf{b} = $ $\begin{bmatrix}
#    74
#    \end{bmatrix} $
#
# 9. $\mathbf{b}\mathbf{b}^T = $ $\begin{bmatrix}
#    1 & -3 & -8 \\
#    -3 & 9 & 24 \\
#    -8 & 24 & 64
#    \end{bmatrix} $
#
# 10. $\mathbf{b}+\mathbf{c}^T$ cannot be computed since $\mathbf{b}$ has $3$ rows and $1$ column but $\mathbf{c}^T$ has $1$ row and $3$ columns.
#
# 11. $\mathbf{b}^T\mathbf{b}^T$ cannot be computed since $\mathbf{b}^T$ has $1$ row and $3$ columns.
#
# 12. $\mathbf{A}^{-1}b = $ $\begin{bmatrix}
#     6 \\
#     4 \\
#     -5
#     \end{bmatrix} $
#
# 13. $\mathbf{A}\circ \mathbf{A} = $ $\begin{bmatrix}
#     1 & 4 & 9 \\
#     4 & 16 & 25 \\
#     9 & 25 & 36
#     \end{bmatrix} $
#
# 14. $\mathbf{b}\circ \mathbf{c} = $ $\begin{bmatrix}
#     -4 \\
#     -9 \\
#     48
#     \end{bmatrix} $

# %% [markdown]
# ## 6
# **Eigenvectors and eigenvalues**. Eigenvectors and eigenvalues are useful for some machine learning algorithms, but the concepts take time to solidly grasp. For an intuitive review of these concepts, explore this [interactive website at Setosa.io](http://setosa.io/ev/eigenvectors-and-eigenvalues/). Also, the series of linear algebra videos by Grant Sanderson of 3Brown1Blue are excellent and can be viewed on youtube [here](https://www.youtube.com/playlist?list=PLZHQObOWTQDPD3MizzM2xVFitgF8hE_ab).
#
# 1. Calculate the eigenvalues and corresponding eigenvectors of matrix $\mathbf{A}$ above, from the last question.
# 2. Choose one of the eigenvector/eigenvalue pairs, $\mathbf{v}$ and $\lambda$, and show that $\mathbf{A} \mathbf{v} = \lambda \mathbf{v}$. Also show that this relationship extends to higher orders: $\mathbf{A} \mathbf{A} \mathbf{v} = \lambda^2 \mathbf{v}$
# 3. Show that the eigenvectors are orthogonal to one another (e.g. their inner product is zero). This is true for real, symmetric matrices.

# %% [markdown]
# **ANSWER**
# 1. To find eigenvalues, $det(\mathbf{A}-\lambda \mathbf{I}) = $
# $\begin{vmatrix}
# 1-\lambda & 2 & 3 \\
# 2 & 4-\lambda & 5 \\
# 3 & 5 & 6-\lambda
# \end{vmatrix}$
# $= -\lambda^3 + 11\lambda^2 +4\lambda -1 = 0 $. Solve the equation, we have
# $\lambda = 0.17092, -0.51573, 11.34481 $.
#
#    To find eigenvectors, solve $(\mathbf{A}-\lambda \mathbf{I})\mathbf{v} = \mathbf{0}$ for each eigenvalue $\lambda$.
#
#    For $\lambda = 0.17092$, we have $\mathbf{v}_1 = $
#    $\begin{pmatrix}
#    1.80194 \\
#    -2.24698 \\
#    1
#    \end{pmatrix}$
#
#    For $\lambda = -0.51573$, we have $\mathbf{v}_2 = $
#    $\begin{pmatrix}
#    -1.24698 \\
#    -0.55496 \\
#    1
#    \end{pmatrix}$
#
#    For $\lambda = 11.34481$, we have $\mathbf{v}_3 = $
#    $\begin{pmatrix}
#    0.44504 \\
#    0.80194 \\
#    1
#    \end{pmatrix}$
#
# 2. Verify when
#
#    $\lambda = 0.17092, \mathbf{Av} = \lambda \mathbf{v}. \mathbf{Av} =
#    \begin{bmatrix}
#    1 & 2 & 3 \\
#    2 & 4 & 5 \\
#    3 & 5 & 6
#    \end{bmatrix}
#    \begin{pmatrix}
#    1.80194 \\
#    -2.24698 \\
#    1
#    \end{pmatrix} =
#    \begin{pmatrix}
#    0.30798 \\
#    -0.38404 \\
#    0.17092
#    \end{pmatrix} =
#    \lambda \mathbf{v} = 0.17092
#    \begin{pmatrix}
#    1.80194 \\
#    -2.24698 \\
#    1
#    \end{pmatrix}$.
#
#    The relationship extends to higher order,
#
#    $\mathbf{AAv} =
#    \begin{bmatrix}
#    14 & 25& 31 \\
#    25 & 45 & 56 \\
#    31 & 56 & 70
#    \end{bmatrix}
#    \begin{pmatrix}
#    1.80194 \\
#    -2.24698 \\
#    1
#    \end{pmatrix} =
#    \begin{pmatrix}
#    0.05266 \\
#    -0.0656 \\
#    0.02926
#    \end{pmatrix} = \lambda^2 \mathbf{v} = 0.0292
#    \begin{pmatrix}
#    1.80194 \\
#    -2.24698 \\
#    1
#    \end{pmatrix}$.
#
# 3. The inner product of $\mathbf{v}_1$ and $\mathbf{v}_2$ is $1.80194 * (-1.24698) + (-2.24698 * -0.55496) = 0$. So $\mathbf{v}_1$ and $\mathbf{v}_2$ are orthogonal. Same rule applies to any arbitrary pair of eigenvectors.

# %% [markdown]
# # Numerical Programming

# %% [markdown]
# ## 7
# Speed comparison between vectorized and non-vectorized code. Begin by creating an array of 10 million random numbers using the numpy random.randn module. Compute the sum of the squares first in a for loop, then using Numpy's `dot` module. Time how long it takes to compute each and report the results and report the output. How many times faster is the vectorized code than the for loop approach?
#
# *Note: all code should be well commented, properly formatted, and your answers should be output using the `print()` function as follows (where the # represents your answers, to a reasonable precision):
#
# `Time [sec] (non-vectorized): ######`
#
# `Time [sec] (vectorized):     ######`
#
# `The vectorized code is ##### times faster than the vectorized code`

# %% [markdown]
# **ANSWER**

# %%
import numpy as np
import time

# Generate the random samples
array = np.random.randn(10000000)

# Compute the sum of squares the non-vectorized way (using a for loop)
start1 = time.time()
result1 = 0
for i in array:
    result1 = result1 + i*i
end1 = time.time()

# Compute the sum of squares the vectorized way (using numpy)
start2 = time.time()
result2 = np.dot(array, array)
end2 = time.time()

# Print the results
print("Time [sec] (non-vectorized): %.5f"%(end1-start1))
print("Time [sec] (vectorized):     %.5f"%(end2-start2))
timedifference = (end1-start1)/(end2-start2)
print("The vectorized code is %d times faster than the non-vectorized code" % timedifference)
# Out:
# Time [sec] (non-vectorized): 1.90185
# Time [sec] (vectorized):     0.00576
# The vectorized code is 330 times faster than the non-vectorized code

# %% [markdown]
# ## 8
# One popular Agile development framework is Scrum (a paradigm recommended for data science projects). It emphasizes the continual evolution of code for projects, becoming progressively better, but starting with a quickly developed minimum viable product. This often means that code written early on is not optimized, and that's a good thing - it's best to get it to work first before optimizing. Imagine that you wrote the following code during a sprint towards getting an end-to-end system working. Vectorize the following code and show the difference in speed between the current implementation and a vectorized version.
#
# The function below computes the function $f(x,y) = x^2 - 2 y^2$ and determines whether this quantity is above or below a given threshold, `thresh=0`. This is done for $x,y \in \{-4,4\}$, over a 2,000-by-2,000 grid covering that domain.
#
# (a) Vectorize this code and demonstrate (as in the last exercise) the speed increase through vectorization and (b) plot the resulting data - both the function $f(x,y)$ and the thresholded output - using [`imshow`](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.imshow.html?highlight=matplotlib%20pyplot%20imshow#matplotlib.pyplot.imshow) from `matplotlib`.
#
# *Hint: look at the `numpy` [`meshgrid`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.meshgrid.html) documentation*

# %%
import numpy as np
import time
import matplotlib.pyplot as plt

# Initialize variables for this exerise
x = np.linspace(-4, 4, 2000)
y = np.linspace(-4, 4, 2000)
thresh = 0
# Nonvectorized implementation
start1 = time.time()
for i in x:
    for j in y:
        f1 = i**2 - 2*j**2
end1 = time.time()
# Vectorized implementation
start2 = time.time()
xx, yy = np.meshgrid(x,y)
f2 = xx**2 - 2*y**2
end2 = time.time()
# Print the time for each and the speed increase
print("Time [sec] (non-vectorized): %.5f"%(end1-start1))
print("Time [sec] (vectorized):     %.5f"%(end2-start2))
timedifference = (end1-start1)/(end2-start2)
print("The vectorized code is %d times faster than the non-vectorized code" % timedifference)
# Plot the result
plt.contourf(xx, yy, f2, cmap='jet')
plt.colorbar()
plt.show()

thresh_output = (f2 > thresh)
plt.contourf(xx, yy, thresh_output, cmap='jet')
plt.colorbar()
plt.show()
# Out:
# Time [sec] (non-vectorized): 2.73956
# Time [sec] (vectorized):     0.06629
# The vectorized code is 41 times faster than the non-vectorized code

# %% [markdown]
# ## 9
# This exercise will walk through some basic numerical programming exercises.
# 1. Synthesize $n=10^4$ normally distributed data points with mean $\mu=2$ and a standard deviation of $\sigma=1$. Call these observations from a random variable $X$, and call the vector of observations that you generate, $\textbf{x}$.
# 2. Calculate the mean and standard deviation of $\textbf{x}$ to validate (1) and provide the result to a precision of four significant figures.
# 3. Plot a histogram of the data in $\textbf{x}$ with 30 bins
# 4. What is the 90th percentile of $\textbf{x}$? The 90th percentile is the value below which 90% of observations can be found.
# 5. What is the 99th percentile of $\textbf{x}$?
# 6. Now synthesize $n=10^4$ normally distributed data points with mean $\mu=0$ and a standard deviation of $\sigma=3$. Call these observations from a random variable $Y$, and call the vector of observations that you generate, $\textbf{y}$.
# 7. Plot the histogram of the data in $\textbf{y}$ on a (new) plot with the histogram of $\textbf{x}$, so that both histograms can be seen and compared.
# 8. Using the observations from $\textbf{x}$ and $\textbf{y}$, estimate $E[XY]$

# %% [markdown]
# **ANSWER**

# %%
import numpy as np
import matplotlib.pyplot as plt
# 1
mu_x = 2
sigma_x = 1
X = sigma_x * np.random.randn(10000) + mu_x # Generate an array of size 10000, mean 2 and stdev of 1
# 2
avg = X.mean() # calculate the mean of the generated X observations
print("2. The mean of X is %.3f" % avg)
stdev = X.std() # calculate the standard deviation
print("   The standard deviation of X is %.3f" %stdev)
# 3
num_bins = 30
plt.figure()
plt.subplot(3,1,1)
n, bins, patches = plt.hist(X, num_bins, facecolor='blue', alpha=0.5) #plot the histogram with 30 bins
plt.title('histogram of data in X with 30 bins')
plt.xlabel('data')
plt.ylabel('frequency')
#plt.show()
# 4
percentile90 = np.percentile(X, 90)
print("4. The 90th percentile of X is", percentile90)
# 5
percentile99 = np.percentile(X, 99)
print("5. The 99th percentile of X is", percentile99)
# 6
mu_y = 0
sigma_y = 3
Y = sigma_y * np.random.randn(10000) + mu_y # Generate an array of size 10000, mean 0 and stdev of 3
# 7
plt.subplot(3,1,3)
n, bins, patches = plt.hist(Y, num_bins, facecolor='blue', alpha=0.5) #plot the histogram with 30 bins
plt.title('histogram of data in Y with 30 bins')
plt.xlabel('data')
plt.ylabel('frequency')
plt.show()
# 8
XY = np.multiply(X,Y) # estimate E[XY] by element-wise multiply of two matrices, and take the average 
avg_XY = XY.mean()
print("8. Assume X and Y are independent, E[XY] = E[X]*E[Y] = 0")
print("   The simulated calculation result: E[XY] =", avg_XY)
# Out:
# 2. The mean of X is 2.005
#    The standard deviation of X is 1.004
# 4. The 90th percentile of X is 3.27344714888
# 5. The 99th percentile of X is 4.33148610154
# 8. Assume X and Y are independent, E[XY] = E[X]*E[Y] = 0
#    The simulated calculation result: E[XY] = -0.0294899099112

# %% [markdown]
# ## 10
# Estimate the integral of the function $f(x)$ on the interval $0\leq x < 2.5$ assuming we only know the following points from $f$:
#
# *Table 1. Dataset containing n=5 observations*
#
# | $x_i$ | 0.0 | 0.5 | 1.0 | 1.5 | 2.0 |
# |-|-|-|-|-|-|
# | $y_i$ | 6 | 7 | 8 | 4 | 1 |

# %% [markdown]
# **ANSWER**
#
# Estimate using midpoint rectangle rule:
#
# step size is $0.5$, $\int f(x)dx \approx 0.5*\frac{7+6}{2}+0.5*\frac{8+7}{2}+0.5*\frac{8+4}{2}+0.5*\frac{4+1}{2} = 11.25$

# %% [markdown]
# # Version Control via Git

# %% [markdown]
# ## 11
# Complete the [Atlassian Git tutorial](https://www.atlassian.com/git/tutorials/what-is-version-control), specifically the following sections. Try each concept that's presented. For this tutorial, instead of using BitBucket, use Github. Create a github account here if you don't already have one: https://github.com/
# 1. [What is version control](https://www.atlassian.com/git/tutorials/what-is-version-control)
# 2. [What is Git](https://www.atlassian.com/git/tutorials/what-is-git)
# 3. [Install Git](https://www.atlassian.com/git/tutorials/install-git)
# 4. [Setting up a repository](https://www.atlassian.com/git/tutorials/install-git)
# 5. [Saving changes](https://www.atlassian.com/git/tutorials/saving-changes)
# 6. [Inspecting a repository](https://www.atlassian.com/git/tutorials/inspecting-a-repository)
# 7. [Undoing changes](https://www.atlassian.com/git/tutorials/undoing-changes)
# 8. [Rewriting history](https://www.atlassian.com/git/tutorials/rewriting-history)
# 9. [Syncing](https://www.atlassian.com/git/tutorials/syncing)
# 10. [Making a pull request](https://www.atlassian.com/git/tutorials/making-a-pull-request)
# 11. [Using branches](https://www.atlassian.com/git/tutorials/using-branches)
# 12. [Comparing workflows](https://www.atlassian.com/git/tutorials/comparing-workflows)
#
# For your answer, affirm that you either completed the tutorial or have previous experience with all of the concepts above. Do this by typing your name below and selecting the situation that applies from the two options in brackets.

# %% [markdown]
# **ANSWER**
#
# *I, **Yifan Li**, affirm that I have **completed the above tutorial***

# %% [markdown]
# ## 12
# Using Github to create a static HTML website:
# 1. Create a branch in your `machine-learning-course` repo called "gh-pages" and checkout that branch (this will provide an example of how to create a simple static website using [Github Pages](https://pages.github.com/))
# 2. Create a file called "index.html" with the contents "Hello World" and add, commit, and push it to that branch.
# 3. Submit the following: (a) a link to your github repository and (b) a link to your new "Hello World" website. The latter should be at the address https://[USERNAME].github.io/ECE590-assignment0 (where [USERNAME] is your github username).

# %% [markdown]
# **ANSWER**
#
# (a). Link to my github repository:
#     https://github.com/Coolifan/machine-learning-course
#
# (b). Link to my "Hello World" website:
#     https://coolifan.github.io/machine-learning-course/

# %% [markdown]
# # Exploratory Data Analysis
# ## 13
# Here you'll bring together some of the individual skills that you demonstrated above and create a Jupyter notebook based blog post on data analysis.
#
# 1. Find a dataset that interests you and relates to a question or problem that you find intriguing
# 2. Using a Jupyter notebook, describe the dataset, the source of the data, and the reason the dataset was of interest.
# 3. Check the data and see if they need to be cleaned: are there missing values? Are there clearly erroneous values? Do two tables need to be merged together? Clean the data so it can be visualized.
# 3. Plot the data, demonstrating interesting features that you discover. Are there any relationships between variables that were surprising or patterns that emerged? Please exercise creativity and curiosity in your plots.
# 4. What insights are you able to take away from exploring the data? Is there a reason why analyzing the dataset you chose is particularly interesting or important? Summarize this as if your target audience was the readership of a major news organization - boil down your findings in a way that is accessible, but still accurate.
# 5. Create a public repository on your github account titled "machine-learning-course". In it, create a readme file that contains the heading "ECE590: Introductory Machine Learning for Data Science". Add, commit, and push that Jupyter notebook to the master branch. Provide the link to the that post here.

# %% [markdown]
# **ANSWER**
#
# 1 & 2. The dataset that I chose is a detailed dataset on how wide an audience the 2010 FIFA World Cup reached on television in different countries published by FIFA (Fédération Internationale de Football Association, French for "International Federation of Association Football"). The dataset was further extracted and summurized by Nate Silver from fivethirtyeight.com.(Link:https://fivethirtyeight.com/features/how-to-break-fifa/)
# I am personally very interested in soccer and I have been watching every single FIFA World Cup event since 2002. FIFA World Cup 2018 will be held in Russia in this summer, and I am excited about it. The dataset mainly shows the size of TV audiences for many countries and using the dataset, we can come to some reasonable estimates of how lucrative each country’s TV market is.
#
# The dataset includes the following variables:
#
# country : FIFA member country
# confederation : Confederation to which country belongs
#
# population_share : Country's share of global population (percentage)
#
# tv_audience_share : Country's share of global world cup TV Audience (percentage)
#
# gdp_weighted_share : Country's GDP-weighted audience share (percentage)
#
#
#
# 3.The dataset is very clean and well-organized. There are no missing values or erroneous values. There is only one table, so no merging is needed.
#
# 4 & 5. This dataset demonstrates the distribution of global soccer fans/viewers. Specifically, wealthier countries generally have higher GDP-weighted share and higher ratio of TV audience relative to the country's total population. The majority of the audience come from Asia, Europe and South America, while North American and European countries typically have higher GDP-weighted share because of more developed economy. In total, the USA represented 11 percent of the GDP-weighted audience for the 2010 World Cup, followed by Japan (9 percent), China (7 percent), Germany (6 percent), Brazil (5 percent), and the United Kingdom, Italy and France (4 percent each). Those eight countries alone accounted for more than half of the GDP-weighted World Cup audience. In 2010, African countries represented about 25 percent of FIFA members but (even though the World Cup was played in Africa) only about 3 percent of the tournament’s GDP-weighted TV audience. By contrast, Asia and South America are underrepresented in FIFA.
#
# 6.Link to the master branch of my repo: https://github.com/Coolifan/machine-learning-course

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
mydata = pd.read_csv('./fifa_countries_audience.csv')
mydata
# Out:
#                       country confederation  population_share  \
# 0               United States      CONCACAF               4.5
# 1                       Japan           AFC               1.9
# 2                       China           AFC              19.5
# 3                     Germany          UEFA               1.2
# 4                      Brazil      CONMEBOL               2.8
# 5              United Kingdom          UEFA               0.9
# 6                       Italy          UEFA               0.9
# 7                      France          UEFA               0.9
# 8                      Russia          UEFA               2.1
# 9                       Spain          UEFA               0.7
# 10                South Korea           AFC               0.7
# 11                  Indonesia           AFC               3.5
# 12                     Mexico      CONCACAF               1.7
# 13                     Turkey          UEFA               1.1
# ...

# %%
mydata[mydata.tv_audience_share==mydata['tv_audience_share'].max()]
# We can see that the country that has the largest TV audience share of FIFA World Cup is China,
# and China also has the largest population, which makes sense.
# Out:
#   country confederation  population_share  tv_audience_share  \
# 2   China           AFC              19.5               14.8
#
#    gdp_weighted_share
# 2                 7.3

# %%
mydata[mydata.gdp_weighted_share==mydata['gdp_weighted_share'].max()]
# However, also China has the largest population and TV audience share, the country that has the 
#most GDP-weighted audience share is the USA, which also makes sense. 
#Although the U.S. had slightly below-average World Cup viewership relative to its population,
#its large, wealthy population was enough to make up for that.
# Out:
#          country confederation  population_share  tv_audience_share  \
# 0  United States      CONCACAF               4.5                4.3
#
#    gdp_weighted_share
# 0                11.3

# %%
g = mydata.groupby('confederation')
g.sum()
#The sum of share by each confederation/continent

# We can compare and summurize the data by region/confederation and take the sum and average values of each variable.
# As we can see, Asia (AFC) has the most average total population, but South America(CONMEBOL) has the most 
# average TV audience share. However, Europe(UEFA) and North America(CONCACAF) countries have higher GDP-weighted
# share relative to their population share. Africa contries(CAF) has a moderate size of population but relatively 
# small size of TV audience share, perhaps due to the lack of electricity / home appliance.
# Out:
#                population_share  tv_audience_share  gdp_weighted_share
# confederation
# AFC                        58.9               42.6                31.6
# CAF                        14.9                8.6                 2.6
# CONCACAF                    7.8                9.8                15.8
# CONMEBOL                    5.6               13.5                10.3
# OFC                         0.2                0.2                 0.1
# UEFA                       12.4               25.2                39.0

# %%
g.mean()
# Average share percent of each continent/confederation
# Out:
#                population_share  tv_audience_share  gdp_weighted_share
# confederation
# AFC                    1.369767           0.990698            0.734884
# CAF                    0.298000           0.172000            0.052000
# CONCACAF               0.260000           0.326667            0.526667
# CONMEBOL               0.560000           1.350000            1.030000
# OFC                    0.016667           0.016667            0.008333
# UEFA                   0.269565           0.547826            0.847826

# %%
g.mean().plot()
plt.title('Average share data of different confederations')
plt.show()

# %%
mydata[mydata['tv_audience_share']/mydata['population_share'] > 1.5]
#here, we compare the tv audience share of the country with the country's population share by 
#calculating the ratio of these two variables.
#we can see that we have some countries that have a resulted ratio of at least 1.5. 
#We can draw the conclusion that soccer should be very popular in these countries.
#We can also see that the regions/confederation of these countries are mainly distributed among Asia(AFC),
#Europe(UEFA) and America(CONMEBOL and CONCACAF). Soccer is also popular in Africa, but the TV audience share 
#in Africa is really low, perhaps due to the lack of electricity / home appliance.
# Out:
#                country confederation  population_share  tv_audience_share  \
# 1                Japan           AFC               1.9                4.9
# 3              Germany          UEFA               1.2                2.9
# 4               Brazil      CONMEBOL               2.8                7.1
# 5       United Kingdom          UEFA               0.9                2.1
# 6                Italy          UEFA               0.9                2.1
# 7               France          UEFA               0.9                2.0
# 9                Spain          UEFA               0.7                1.8
# 10         South Korea           AFC               0.7                1.8
# 11           Indonesia           AFC               3.5                6.7
# 12              Mexico      CONCACAF               1.7                3.2
# 13              Turkey          UEFA               1.1                2.3
# 14            Thailand           AFC               1.0                2.4
# ...
